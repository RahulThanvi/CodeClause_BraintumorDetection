# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import os

path = os.listdir('C:/Users/91992/Desktop/codeclause2 bt/Training')
classes = {'no_tumor':0,'pituitary_tumor':1}

# %%
import cv2
X = []
Y = []
for cls in classes:
    pth = 'C:/Users/91992/Desktop/codeclause2 bt/Training/'+cls
    for j in os.listdir(pth):
        img = cv2.imread(pth + '/' + j, 0)
        img = cv2.resize(img,(200,200))
        X.append(img)
        Y.append(classes[cls])

# %%
np.unique(Y)
# Out:
# array([0, 1])

# %%
X = np.array(X)
Y = np.array(Y)

# %%
pd.Series(Y).value_counts()
# Out:
# 1    827
# 0    395
# dtype: int64

# %%
X.shape
# Out:
# (1222, 200, 200)

# %%
plt.imshow(X[0], cmap='gray')

# %%
X_updated = X.reshape(len(X), -1)
X_updated.shape
# Out:
# (1222, 40000)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_updated, Y, random_state=10, test_size=20)

# %%
xtrain.shape, xtest.shape
# Out:
# ((1202, 40000), (20, 40000))

# %%
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
xtrain = xtrain/255
xtest = xtest/255
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
# Out:
# 255 0
# 255 0
# 1.0 0.0
# 1.0 0.0

# %%
from sklearn.decomposition import PCA

# %%
print(xtrain.shape, xtest.shape)

pca = PCA(.98)
pca_train = xtrain
pca_test = xtest
# Out:
# (1202, 40000) (20, 40000)

# %%
# print(pca_train.shape, pca_test.shape)
# print(pca.n_components_)
# print(pca.n_features_)

# %% [markdown]
# Training the Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
import warnings
warnings.filterwarnings('ignore')

lg= LogisticRegression(C=0.1)
lg.fit(pca_train, ytrain)
# Out:
# LogisticRegression(C=0.1)

# %%
sv = SVC()
sv.fit(pca_train,ytrain)
# Out:
# SVC()

# %%
print("Training Score:", lg.score(pca_train,ytrain))
print("Testing Score:", lg.score(pca_test, ytest))
# Out:
# Training Score: 1.0
# Testing Score: 0.95

# %%
print("Training Score:", sv.score(pca_train, ytrain))
print("Testing Score:", sv.score(pca_test, ytest))
# Out:
# Training Score: 0.9933444259567388
# Testing Score: 1.0

# %%
pred = sv.predict(pca_test)
np.where(ytest!=pred)
# Out:
# (array([], dtype=int64),)

# %%
pred[6]
# Out:
# 0

# %%
ytest[6]
# Out:
# 0

# %% [markdown]
# TEST MODEL

# %%
dec = {0:"No tumor", 1:"Positive Tumor"}

# %%
plt.figure(figsize=(12,8))
p = os.listdir('C:/Users/91992/Desktop/codeclause2 bt/Testing/')
c=1
for i in os.listdir('C:/Users/91992/Desktop/codeclause2 bt/Testing/no_tumor/')[:16]:
    plt.subplot(4,4,c)
     
    img = cv2.imread('C:/Users/91992/Desktop/codeclause2 bt/Testing/no_tumor/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = sv.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1

# %%
plt.figure(figsize=(12,8))
p = os.listdir('C:/Users/91992/Desktop/codeclause2 bt/Testing/')
c=1
for i in os.listdir('C:/Users/91992/Desktop/codeclause2 bt/Testing/pituitary_tumor/')[:16]:
    plt.subplot(4,4,c)
     
    img = cv2.imread('C:/Users/91992/Desktop/codeclause2 bt/Testing/pituitary_tumor/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = sv.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1
